# %% [markdown]
# # Angular integration

# %% [markdown]
# # import packages and scripts

# %%
# -- import packages
import matplotlib.pyplot as plt
import numpy as np
import sys
import tifffile as tf
from scipy.interpolate import interp1d
from scipy.ndimage.filters import gaussian_filter
import scipy.fftpack

#-- files and folders
src_dir  = '/Users/fivos/Documents/Projects/12 WAXS APS amorphous ices/02_analysis/github_repo/scr/'
path = '/Users/fivos/Documents/Projects/12 WAXS APS amorphous ices/00_data/02_eHDA007_KW06/'
file_name = ['LDAII_after_heating_eHDA007_to_118/eHDA007_1s120f_299.331-00530.tif','eHDA007_1s120f_82.071-00256.tif']
ceo2_path = '/Users/fivos/Documents/Projects/12 WAXS APS amorphous ices/00_data/00_alignment/CeO2_test_0p1s10f-00032.tif'

# -- import source files
sys.path.insert(0, src_dir)
from integrators import*
from utilities import *
from corrections import *

# %%
# parameters
cx,cy = 1037,1031 # center

# %% [markdown]
# Q calibration

# %%
CeO2 = np.array(tf.imread(ceo2_path))

# %% [markdown]
# find center (fit ring for better precision)

# %%
# load files
bg = np.array(tf.imread(path+file_name[0]))
raw = np.array(tf.imread(path+file_name[1]))

# ring mask
inner_radius,width,spacing,num_rings=60,6,0,1
mask = ring_mask(raw,(cx,cy),inner_radius=inner_radius,width=width,spacing=spacing,num_rings=num_rings)

# plots
dx,dy = 150,150
plt.figure(figsize=[10,5])
plt.subplot(1,2,1)
vmin,vmax = 0,5e5#2*1e6,5*1e6#4e6,7e5
plt.imshow(CeO2[cx-dx:cx+dx,cy-dy:cy+dy],origin='lower',interpolation='none',vmax =vmax,vmin=vmin)

plt.subplot(1,2,2)
#vmin,vmax = 4.5*1e6,5*1e6#4e6,7e5
plt.imshow(CeO2[cx-dx:cx+dx,cy-dy:cy+dy]*mask[cx-dx:cx+dx,cy-dy:cy+dy],origin='lower',interpolation='none',vmax =vmax,vmin=vmin)

#plt.colorbar()
plt.show()

# %%
# parameters
n_bins = 3500 # number of bins
min_x,max_x = 0,760#n_bins
mask_thr = 0
qmax = 2. # for the first peak 

# angular intergation
qbin,Iq = angular_average(CeO2, (cx,cy),None,threshold=mask_thr, nx=n_bins,  min_x=min_x, max_x=max_x)

#q-calib
Imax = max(Iq)
qbin_max = qbin[Iq==Imax]#-1
q = qbin*(qmax/qbin_max)

# plot for comparison
plt.figure()
plt.plot(q,Iq,'b-',label='CeO2')

#plt.axvline(x=q[15],c='gray',ls='--')
#plt.axvline(x=q[30],c='gray',ls='--')
plt.axvline(x=qmax,c='gray',ls='-')
plt.axvline(x=2.3,c='gray',ls='--')
plt.axhline(y=0,c='gray')
plt.ylabel(r'$I(Q)$')
plt.xlabel(r'$Q$ $\rm(\AA)$')
plt.xlim([0,5])
plt.legend()
plt.show()

np.save('/Users/fivos/Desktop/CeO2',[q,Iq])

# %% [markdown]
# ##### Subtract background

# %%
# ring mask
inner_radius,width,spacing,num_rings=15,15,0,1
mask = ring_mask(raw,(cx,cy),inner_radius=inner_radius,width=width,spacing=spacing,num_rings=num_rings)

dx,dy = 30,30
#norm = np.sum(raw[cx-dx:cx+dx,cy-dy:cy+dy])/np.sum(bg[cx-dx:cx+dx,cy-dy:cy+dy])
norm = np.sum(raw*mask)/np.sum(bg*mask)
print norm
im = raw-bg*norm

dx,dy = 100,100
plt.figure(figsize=[14,3])
vmax,vmin = 3e6,1e6

plt.subplot(1,3,1)
plt.imshow(raw[cx-dx:cx+dx,cy-dy:cy+dy],vmax =vmax,vmin=vmin,origin='lower',interpolation='none')
plt.colorbar()
plt.title('raw')

plt.subplot(1,3,2)
plt.imshow(raw[cx-dx:cx+dx,cy-dy:cy+dy]*mask[cx-dx:cx+dx,cy-dy:cy+dy],vmax =vmax,vmin=vmin,origin='lower',interpolation='none')
plt.colorbar()
plt.title('raw')

plt.subplot(1,3,3)
plt.imshow(bg[cx-dx:cx+dx,cy-dy:cy+dy]*mask[cx-dx:cx+dx,cy-dy:cy+dy]*norm,vmax =vmax,vmin=vmin,origin='lower',interpolation='none')
plt.colorbar()
plt.title('background')
plt.show()
# Out:
# 1.06395483775

# %% [markdown]
# plot for comparison

# %%
dx,dy = 200,200
plt.figure(figsize=[15,3])
vmax,vmin = 4e6,7e5

plt.subplot(1,3,1)
plt.imshow(raw[cx-dx:cx+dx,cy-dy:cy+dy],vmax =vmax,vmin=vmin,origin='lower',interpolation='none')
plt.colorbar()
plt.title('raw')

plt.subplot(1,3,2)
plt.imshow(bg[cx-dx:cx+dx,cy-dy:cy+dy],vmax =vmax,vmin=vmin,origin='lower',interpolation='none')
plt.colorbar()
plt.title('background')

plt.subplot(1,3,3)
plt.imshow(im[cx-dx:cx+dx,cy-dy:cy+dy],vmax =vmax,vmin=vmin,origin='lower',interpolation='none')
plt.colorbar()
plt.title('subtracted')

plt.show()

# %% [markdown]
# Angular integration and Q-calibration (use the CeO2 for more precise q calibration)

# %%
# parameters
n_bins = 1500 # number of bins
min_x,max_x = 0,760#n_bins
mask_thr = 0
qmax = 2.1 # for HDA at 89K

# angular intergation
qbin,Iq0 = angular_average(raw, (cx,cy),None,threshold=mask_thr, nx=n_bins,  min_x=min_x, max_x=max_x)
qbin,Iq1 = angular_average(bg*norm, (cx,cy),None,threshold=mask_thr, nx=n_bins,  min_x=min_x, max_x=max_x)
qbin,Iq2 = angular_average(im, (cx,cy),None,threshold=mask_thr, nx=n_bins,  min_x=min_x, max_x=max_x)

# quick and dirty q-calib
Imax = max(Iq2)
qbin_max = qbin[Iq2==Imax]#-1
q = qbin*(qmax/qbin_max)

# plot for comparison
plt.figure()
plt.plot(q,Iq0,'b-',label='raw')
plt.plot(q,Iq1,'r-',label='background')
plt.plot(q,Iq2,'g-',label='subtracted')
#plt.axvline(x=q[15],c='gray',ls='--')
#plt.axvline(x=q[30],c='gray',ls='--')
plt.axvline(x=qmax,c='gray',ls='-')
plt.axhline(y=0,c='gray')
plt.ylabel(r'$I(Q)$')
plt.xlabel(r'$Q$ $\rm(\AA)$')
plt.xlim([0,5])
plt.legend()
plt.show()

# %% [markdown]
# Dark images

# %%
path = '/Users/fivos/Documents/Projects/12 WAXS APS amorphous ices/00_data/02_eHDA007_KW06/'
file_name = 'Dark_2s120f-00350.dark.tif'
dark = np.array(tf.imread(path+file_name))

qbin,Iq_d = angular_average(dark, (cx,cy),None,threshold=mask_thr, nx=n_bins,  min_x=min_x, max_x=max_x)

plt.figure(figsize=[10,8])
plt.subplot(2,2,1)
vmin,vmax = 2.5*1e5,3.*1e5
plt.imshow(bg,vmax =vmax,vmin=vmin,origin='lower',interpolation='none')
plt.colorbar()
plt.title('background')

plt.subplot(2,2,2)
vmin,vmax = 2.5*1e5,3.*1e5
plt.imshow(dark,origin='lower',interpolation='none',vmax =vmax,vmin=vmin)
plt.colorbar()
plt.title(file_name)
plt.title('dark')

plt.subplot(2,2,3)
plt.plot(q,Iq1-Iq1[0],'r-',label='background')
plt.plot(q,Iq_d,'b-',label='dark')
plt.ylabel(r'$I(Q)$')
plt.xlabel(r'$Q$ $\rm(\AA)$')
plt.legend()

plt.subplot(2,2,4)
plt.plot(q,Iq_d,'b-',label='dark')
plt.ylabel(r'$I(Q)$')
plt.xlabel(r'$Q$ $\rm(\AA)$')
plt.legend()
plt.tight_layout()

plt.show()

# %% [markdown]
# flat field correction

# %%
path = '/Users/fivos/Documents/Projects/12 WAXS APS amorphous ices/02_analysis/05 SCRIPTS/05 Chris/'
file_name = 'PE_flat-field_Jul-2014.tif'
flat_field = np.array(tf.imread(path+file_name))

qbin,Iq_f = angular_average(flat_field, (cx,cy),None,threshold=mask_thr, nx=n_bins,  min_x=min_x, max_x=max_x)
qbin,Iq_cf = angular_average(im*flat_field, (cx,cy),None,threshold=mask_thr, nx=n_bins,  min_x=min_x, max_x=max_x)

plt.figure(figsize=[10,8])

plt.subplot(2,2,1)
vmin,vmax = 0.99,1.01
plt.imshow(flat_field,origin='lower',interpolation='none',vmax =vmax,vmin=vmin)
plt.colorbar()
plt.title(file_name)
plt.title('Flat field')

plt.subplot(2,2,2)
plt.plot(q,Iq_f,'b-',label='flat field')
plt.ylabel(r'$I(Q)$')
plt.xlabel(r'$Q$ $\rm(\AA)$')
plt.legend()


plt.subplot(2,2,3)
plt.plot(q,Iq_cf,'b-',label='flat field')
plt.plot(q,Iq2,'r-',label='original')
plt.ylabel(r'$I(Q)$')
plt.xlabel(r'$Q$ $\rm(\AA)$')
plt.legend()


plt.subplot(2,2,4)
plt.plot(q,Iq2-Iq_cf,'g-',label='original - flat field')
#plt.plot(q,Iq,'r-',label='original')
plt.ylabel(r'$I(Q)$')
plt.xlabel(r'$Q$ $\rm(\AA)$')
plt.legend()
plt.tight_layout()

plt.show()

# %% [markdown]
# Radial integration

# %%
# parameters
inner_radius,width,spacing,num_rings=350,100,0,1
n_phi_bins,min_bin,max_bin = 50,-np.pi,np.pi
thr = 1e4

# ring mask
mask = ring_mask(im,(cx,cy),inner_radius=inner_radius,width=width,spacing=spacing,num_rings=num_rings)

# radial integration
I = radial_average(im,calibrated_center=(cx,cy),mask=mask,nx=n_phi_bins,min_x=min_bin,max_x=max_bin)
phi,Iphi = I[0]*180./np.pi+180.,I[1]

# plots
dx,dy = 600,600
plt.figure(figsize=[10,3])
vmin,vmax = 4.5*1e5,4.9*1e5#4e6,7e5
plt.subplot(1,2,1)
plt.imshow(im[cx-dx:cx+dx,cy-dy:cy+dy]*mask[cx-dx:cx+dx,cy-dy:cy+dy],origin='lower',interpolation='none',vmax =vmax,vmin=vmin)
plt.colorbar()

plt.subplot(1,2,2)

plt.plot(phi[Iphi>thr],Iphi[Iphi>thr],'bo-')
#plt.ylim([4.82*1e5,5.2*1e5])
plt.xlim([0,360])
plt.ylabel(r'$I(\phi)$')
plt.xlabel(r'$\phi$ (degrees)')
plt.tight_layout()
plt.show()

# %% [markdown]
# Polarization correction (somehow it is very slow)

# %%
pxd = 200*1e-6 #pixel size [m]
L   = 348*1e-3 #sample to detector disctance [m]
nx,ny = len(im[:,0]),len(im[0,:])
polfac = 1 #polarization factor (percent of horizontal polarization)
alpha = pol_corr((cx,cy), L, pxd, polfac, nx,ny)

# %%
plt.figure()
plt.imshow(alpha,origin='lower',interpolation='none')
plt.colorbar()
plt.show()

# %%
# radial integration
I = radial_average(im/alpha,calibrated_center=(cx,cy),mask=mask,nx=n_phi_bins,min_x=min_bin,max_x=max_bin)
phi2,Iphi2 = I[0]*180./np.pi+180.,I[1]

# plots
dx,dy = 600,600
plt.figure(figsize=[10,3])
plt.subplot(1,2,1)
plt.imshow(im[cx-dx:cx+dx,cy-dy:cy+dy]*mask[cx-dx:cx+dx,cy-dy:cy+dy]/alpha[cx-dx:cx+dx,cy-dy:cy+dy],origin='lower',interpolation='none',vmax =vmax,vmin=vmin)
plt.colorbar()

plt.subplot(1,2,2)
plt.plot(phi[Iphi>thr],Iphi[Iphi>thr],'bo-',label='original')
plt.plot(phi2[Iphi2>thr],Iphi2[Iphi2>thr],'go-',label='pol cor')
plt.xlim([0,360])
plt.ylabel(r'$I(\phi)$')
plt.xlabel(r'$\phi$ (degrees)')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# solid angle correction

# %%
const = 1.67#1.67 #dirty fix - must debug solid angle corr
wlen = const*0.1235 # wavelength x-ray [A]

omega = SolAng_corr(q, pxd,  wlen, L)
qbin,Iq = angular_average(im/alpha*flat_field, (cx,cy),None,threshold=mask_thr, nx=n_bins,  min_x=min_x, max_x=max_x)

plt.figure(figsize=[10,4])
plt.subplot(1,2,1)
plt.plot(q,1./omega,'r-',label='solid angl cor')
plt.ylabel(r'$\omega$')
plt.xlabel(r'$Q$ $\rm(\AA)$')

#plt.xlim([0,20])
plt.subplot(1,2,2)
plt.plot(q,Iq,'b-',label='original')
plt.plot(q,Iq/omega,'r-',label='solid angl cor')
plt.axhline(y=0,c='gray')
plt.ylabel(r'$I(Q)$')
plt.xlabel(r'$Q$ $\rm(\AA)$')
plt.xlim([0,20])
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# Compare with fit2D result

# %%
fit2d_path = '/Users/fivos/Documents/Projects/10 WAXS of HDA/02 data/03 CHI data/'
fit2d_file = 'eHDA007_1s120f_82.071-00256.chi'#'''eHDA_DP18_82.03K_0.7s_10f-02582.chi'#'eHDA_DP18_82.03K_0.7s_10f-02582.chi'#eHDA007_KW06_82.00K_1s_180f-01439.chi
data = np.genfromtxt(fit2d_path+fit2d_file,skip_header=5)
q_f2d,Iq_f2d = data[:,0],data[:,1]

# %%
# normalise for comparison
qbin,Iq_py = angular_average(raw/alpha*flat_field, (cx,cy),None,threshold=mask_thr, nx=n_bins,  min_x=min_x, max_x=max_x)

plt.figure(figsize=[10,4])
plt.plot(q_f2d/10.,Iq_f2d/max(Iq_f2d),'b-',label='fit_2d')
plt.plot(q,Iq_py/max(Iq_py)/omega,'r-',label='python')
plt.ylabel(r'$I(Q)_{CS}$')
plt.xlabel(r'$Q$ $\rm(\AA)$')
plt.xlim([0,25])
plt.legend()

plt.show()

# %% [markdown]
# Compton scattering, form factor and weighted form factor

# %%
cs_path = '/Users/fivos/Documents/Projects/12 WAXS APS amorphous ices/02_analysis/05 SCRIPTS/03_Daniel_P/code/Compton_scattering.csv'
form_path = '/Users/fivos/Documents/Projects/12 WAXS APS amorphous ices/02_analysis/05 SCRIPTS/03_Daniel_P/code/Form_factor_quantum.csv'
wf_path = '/Users/fivos/Documents/Projects/12 WAXS APS amorphous ices/02_analysis/05 SCRIPTS/03_Daniel_P/code/Weighting_factor.csv'

data = np.loadtxt(cs_path)
q_cs,Iq_cs0 = data[:,0],data[:,1]
Iq_cs = interp1d(q_cs, Iq_cs0, kind='cubic')(q)

data = np.loadtxt(form_path)
q_f,Iq_f0 = data[:,0],data[:,1]
Iq_f = interp1d(q_f, Iq_f0, kind='cubic')(q)

data = np.loadtxt(wf_path)
q_wf,Iq_wf0 = data[:,0],data[:,1]
Iq_wf = interp1d(q_wf, Iq_wf0, kind='cubic')(q)

# %%
Iq_x = Iq/omega
norm = Iq_x[-1]/(Iq_cs[-1]+Iq_f[-1])
Iq_x /= norm

Iq_x2 = Iq_x-Iq_cs
Sq = (Iq_x2-Iq_f)/Iq_wf+1
#Sq = Iq_x2/Iq_f#+1

print q[Sq==max(Sq)]

plt.figure(figsize=[10,10])
plt.subplot(2,2,1)
plt.plot(q,Iq_cs,'g--')
plt.plot(q,Iq_wf,'b--')
plt.plot(q,Iq_x2,'r-')
plt.ylabel(r'$I(Q)$')
plt.xlabel(r'$Q$ $\rm(\AA)$')
plt.ylim([0,100])

plt.subplot(2,2,2)
plt.plot(q,Iq_f/Iq_wf,'g-')
plt.ylabel(r'$f(Q)/w_f(Q)}$')
plt.xlabel(r'$Q$ $\rm(\AA)$')
plt.xlim([0,25])
plt.legend()

plt.subplot(2,2,3)
plt.plot(q,Sq,'r-')
plt.axhline(y=1,c='gray',ls='--')
plt.ylabel(r'$S(Q)$')
plt.xlabel(r'$Q$ $\rm(\AA)$')
plt.xlim([0,25])
plt.ylim([0,1.8])
plt.legend()

plt.subplot(2,2,4)
plt.plot(q,(Sq-1)*q,'r-')
plt.axhline(y=0,c='gray',ls='--')
plt.ylabel(r'$Q(S(Q)-1)$')
plt.xlabel(r'$Q$ $\rm(\AA)$')
plt.xlim([0,25])
plt.legend()

plt.show()
# Out:
# [ 2.13218391]

# %% [markdown]
# Zero padding and Apodization

# %%
# zero padding
q_zp,Sq_zp = np.ones(len(Sq)*2),np.ones(len(Sq)*2)
q_zp[:len(Sq)] = q
q_zp[len(Sq):] = q+q[-1]
Sq_zp[:len(Sq)]=Sq

# apodization with gaussian funtcion
i_apo = 400 
q_apo = q_zp
print 'Q min apodization = ',q_apo[i_apo]
Sq_apo = Sq_zp
Sq_apo[i_apo:]= gaussian_filter(Sq_zp[i_apo:],sigma=5)

# smoothen low q's
i_low1,i_low2 = 40,70
Sq_apo[:i_low1]=np.zeros(len(Sq_apo[:i_low1]))
Sq_apo[:i_low2]= gaussian_filter(Sq_apo[:i_low2],sigma=5)
Sq_apo[i_low1+10:i_low2] = Sq[i_low1+10:i_low2]

plt.figure(figsize=[10,7])
plt.subplot(2,1,1)
plt.plot(q,Sq,'r-',label='raw')
plt.plot(q_apo,Sq_apo,'b-',label='apodized')
plt.axhline(y=1,c='gray',ls='--')
plt.axvline(x=q_apo[i_apo],c='red',ls='--')
plt.axvline(x=q_apo[i_low1],c='red',ls='--')
plt.ylabel(r'$S(Q)$')
plt.xlabel(r'$Q$ $\rm(\AA)$')
plt.xlim([0,50])
plt.ylim([0.,1.8])
plt.legend()

plt.subplot(2,2,3)
plt.plot(q,Sq,'r-',label='raw')
plt.plot(q_apo,Sq_apo,'b-',label='apodized')
plt.axhline(y=1,c='gray',ls='--')
plt.axvline(x=q_apo[i_low1],c='red',ls='--')
plt.axvline(x=q_apo[i_low2],c='red',ls='--')
plt.ylabel(r'$S(Q)$')
plt.xlabel(r'$Q$ $\rm(\AA)$')
plt.xlim([0,3])
plt.ylim([0.,0.1])
plt.legend()

plt.subplot(2,2,4)
plt.plot(q,Sq,'r-',label='raw')
plt.plot(q_apo,Sq_apo,'b-',label='apodized')
plt.axhline(y=1,c='gray',ls='--')
plt.axvline(x=q_apo[i_apo],c='red',ls='--')
plt.ylabel(r'$S(Q)$')
plt.xlabel(r'$Q$ $\rm(\AA)$')
plt.xlim([12,26])
plt.ylim([0.8,1.2])
plt.legend()

plt.show()
# Out:
# Q min apodization =  6.44482758621

# %% [markdown]
# Fourier transform

# %%
1.0/(2.0*(q[1]-q[0]))
# Out:
# 31.071428571428573

# %%
len(q)/2
# Out:
# 750

# %%
#r = np.linspace(0.01,24.0,len(q))
#r = np.linspace(1.0,25.0,len(q))
#r = np.linspace(0.01, 1.0/(2.0*(q[1]-q[0])), len(q)/2)
r = np.linspace(0.01, 2.0*np.pi/(q[1]-q[0]), len(q)*10)

gr = np.zeros(len(r))
gr_lorch = np.zeros(len(r))

r_apo = np.linspace(0.01,24.0*2,2*len(q))
gr_apo = np.zeros(len(r_apo))

i_max = len(q)-1#200
i_max_apo = len(q_apo)-1
print 'Qmax = ',q[i_max]

c= 0.03343 
rho = 1.13 #[g*cm-3] uHDA=1.17 ; eHDA=1.13 ; VHDA=1.25 ; LDA-II=0.94 
A = 1/(2*rho*c*(np.pi)**2)

def radial_ditribution(q,dq,Sq,r): 
    return q*(Sq-1)*np.sin(q*r)*dq/r

def Lorch(q,r,qmax):
    #a,b = 2.8,0.7
    #delta = np.pi/qmax*(1-np.exp(-np.abs(r-a)/b))
    r1,w1,w2 = 2.8,0.5,4#12
    a = np.pi/qmax
    delta1 = 1-np.exp(-2.77*((r-r1)/w1)**2)
    delta2 = np.sqrt(r)*(0.5+(1./np.pi)*np.arctan2((r-w2),w2/(2*np.pi)))
    delta = a*(delta1+delta2)
    return np.sin(q*delta)/(q*delta)


for i in range(len(r)):
    gr[i] = A*np.sum(radial_ditribution(q[:i_max]*1,q[1]-q[0],Sq[:i_max],r[i]))+1
    gr_lorch[i] = A*np.sum(radial_ditribution(q[:i_max]*1,q[1]-q[0],Sq[:i_max],r[i])*Lorch(q[:i_max],r[i],q[i_max]))+1

for i in range(len(r_apo)):
    gr_apo[i] = A*np.sum(radial_ditribution(q_apo[:i_max_apo]*1,q_apo[1]-q_apo[0],Sq_apo[:i_max_apo],r_apo[i]))+1
    
print r[80] 
print 'grmax = ',max(gr[80:])
print 'rmax = ',r[gr == max(gr[80:])]
# Out:
# Qmax =  24.1298850575
# 2.09251263122
# grmax =  2.9597262982
# rmax =  [ 2.71726642]

# %%
r = np.linspace(0.01, 2.0*np.pi/(q[1]-q[0]), len(q)*10)
gr = np.zeros(len(r))
gr_lorch = np.zeros(len(r))
i_max = len(q)-1

c= 0.03343 
rho = 1.13 #[g*cm-3] uHDA=1.17 ; eHDA=1.13 ; VHDA=1.25 ; LDA-II=0.94 
A = 1/(2*rho*c*(np.pi)**2)

def radial_ditribution(q,dq,Sq,r): 
    return q*(Sq-1)*np.sin(q*r)*dq/r

def Lorch(q,r,qmax):
    #a,b = 2.8,0.7
    #delta = np.pi/qmax*(1-np.exp(-np.abs(r-a)/b))
    r1,w1,w2 = 2.8,0.5,4#12
    a = np.pi/qmax
    delta1 = 1-np.exp(-2.77*((r-r1)/w1)**2)
    delta2 = np.sqrt(r)*(0.5+(1./np.pi)*np.arctan2((r-w2),w2/(2*np.pi)))
    delta = a*(delta1+delta2)
    return np.sin(q*delta)/(q*delta)

for i in range(len(r)):
    gr[i] = A*np.sum(radial_ditribution(q[:i_max]*1,q[1]-q[0],Sq[:i_max],r[i]))+1
    gr_lorch[i] = A*np.sum(radial_ditribution(q[:i_max]*1,q[1]-q[0],Sq[:i_max],r[i])*Lorch(q[:i_max],r[i],q[i_max]))+1

# %%
plt.figure(figsize=[10,4])

plt.subplot(1,2,1)
plt.plot(r,gr_lorch,'b-',label='Lorch',alpha=1,lw=1)
plt.plot(r,gr,'r-',label='raw',alpha=0.7,lw=1.)
#plt.plot(r_apo,(gr_apo-1)+1,'g-',label='Apodized',alpha=0.8)
plt.ylabel(r'$g(r)$')
plt.xlabel(r'$r$ $\rm(\AA)$')
plt.xlim([2.,8])
plt.ylim([0,3.5])
plt.legend()
plt.axhline(y=1,c='gray',ls='--')
plt.axhline(y=0,c='gray',ls='-')

plt.subplot(1,2,2)
plt.plot(r,(gr_lorch-1)*r*r,'b-',label='Lorch',alpha=1,lw=1)
plt.plot(r,(gr-1)*r*r,'r-',label='raw',alpha=0.5,lw=1.)
#plt.plot(r_apo,(gr_apo-1)*r_apo*r_apo,'g-',label='Apodized',alpha=0.8)
plt.ylabel(r'$(g(r)-1)r^2$')
plt.xlabel(r'$r$ $\rm(\AA)$')
plt.xlim([0,25])
plt.ylim([-15,15])
plt.legend()
plt.axhline(y=1,c='gray',ls='--')
plt.axhline(y=0,c='gray',ls='-')
plt.tight_layout()
plt.show()

# %%
gr_path = '/Users/fivos/Documents/Projects/12 WAXS APS amorphous ices/02_analysis/waxs_data/eHDAr256-356_slow_heat_rate_temp_gr_r-1.npy'
temperature,gr_dp,r_dp = np.load(gr_path)

# %%
plt.figure(figsize=[10,4])
plt.subplot(1,2,1)
plt.plot(r,gr_lorch,'b-',label='Lorch',alpha=1)
#plt.plot(r,gr,'r-',label='raw',alpha=0.7,lw=1.)
plt.plot(r_dp,gr_dp[0,:],label='Daniel',c='g')
#plt.plot(r_dp,(gr_dp[0,:]-1)/max(gr_dp[0,:]-1)*max(gr_lorch[80:]-1)+1,label='Daniel',c='g')
plt.xlim([2,8.])
plt.ylim([0.,3.2])
plt.axhline(y=1,c='gray',ls='--')
plt.ylabel(r'$g(r)$')
plt.xlabel(r'$r [\rm \AA]$')
plt.legend()

plt.subplot(1,2,2)
plt.plot(r,(gr_lorch-1)*r*r,'b-',label='Lorch',alpha=1,lw=1)
#plt.plot(r,(gr-1)*r*r,'r-',label='raw',alpha=0.7,lw=1.)
plt.plot(r_dp,(gr_dp[0,:]-1)*r_dp*r_dp,label='Daniel',c='g')
plt.xlim([0,25.])
plt.ylim([-10.,17])
plt.axhline(y=0,c='gray',ls='--')
plt.ylabel(r'$g(r)$')
plt.xlabel(r'$r [\rm \AA]$')
plt.legend()
plt.show()
